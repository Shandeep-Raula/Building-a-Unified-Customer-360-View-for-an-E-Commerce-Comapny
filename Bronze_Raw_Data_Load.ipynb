# %% [markdown]
# #### **Read the Bronze Data and Create Dataframe**

# %%
customer_raw = spark.read.parquet("abfss://40c80f0f-3679-4c38-a09e-d08a91acce75@onelake.dfs.fabric.microsoft.com/d5895aa8-3d8b-42dc-a45c-a7bbeca303e5/Files/Bronze/customers.parquet")
orders_raw = spark.read.parquet("abfss://40c80f0f-3679-4c38-a09e-d08a91acce75@onelake.dfs.fabric.microsoft.com/d5895aa8-3d8b-42dc-a45c-a7bbeca303e5/Files/Bronze/orders.parquet")
payments_raw = spark.read.parquet("abfss://40c80f0f-3679-4c38-a09e-d08a91acce75@onelake.dfs.fabric.microsoft.com/d5895aa8-3d8b-42dc-a45c-a7bbeca303e5/Files/Bronze/payments.parquet")
support_tickets_raw = spark.read.parquet("abfss://40c80f0f-3679-4c38-a09e-d08a91acce75@onelake.dfs.fabric.microsoft.com/d5895aa8-3d8b-42dc-a45c-a7bbeca303e5/Files/Bronze/support_tickets.parquet")
web_activities_raw = spark.read.parquet("abfss://40c80f0f-3679-4c38-a09e-d08a91acce75@onelake.dfs.fabric.microsoft.com/d5895aa8-3d8b-42dc-a45c-a7bbeca303e5/Files/Bronze/web_activities.parquet")
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 3, Finished, Available, Finished)

# %% [markdown]
# #### **Read Bronze Data**

# %%
display(customer_raw.limit(5))
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e64f3449-f544-410d-b7a5-c4a30dbf2bc9)

# %%
display(orders_raw.limit(5))
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 640050b0-0939-419b-b3fb-ea1b16f8efe0)

# %%
display(payments_raw.limit(5))
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 47dacf85-25e6-4dd5-b5d8-c53d2d8d98b9)

# %%
display(support_tickets_raw.limit(5))
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ecd2a768-4357-4b1d-8a22-6ce1a1031add)

# %%
display(web_activities_raw.limit(5))
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6d5ccc54-770b-4327-8abc-940059ee53bd)

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 10, Finished, Available, Finished)
# DataFrame[]

# %% [markdown]
# #### **Save as Bronze Delta Tables**

# %%
customer_raw.write.format("delta").mode("overwrite").saveAsTable("bronze.customers")
orders_raw.write.format("delta").mode("overwrite").saveAsTable("bronze.orders")
payments_raw.write.format("delta").mode("overwrite").saveAsTable("bronze.payments")
support_tickets_raw.write.format("delta").mode("overwrite").saveAsTable("bronze.support")
web_activities_raw.write.format("delta").mode("overwrite").saveAsTable("bronze.web")
# Out:
# StatementMeta(, becd79fe-caed-440a-aca3-977e24fa20a2, 11, Finished, Available, Finished)
